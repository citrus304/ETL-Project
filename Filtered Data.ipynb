# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
soccer_df = pd.read_csv("raw_data.csv")
# Out:
# C:\Users\Yusuf Senturk\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
soccer_df.head(204)
# Out:
#      Unnamed: 0      ID               Name     Instagram ID  Age  \
# 0             0  158023           L. Messi         leomessi   31
# 1             1   20801  Cristiano Ronaldo        cristiano   33
# 2             2  190871          Neymar Jr         neymarjr   26
# 3             3  193080             De Gea  d_degeaofficial   27
# 4             4  192985       K. De Bruyne    kevindebruyne   27
# ..          ...     ...                ...              ...  ...
# 199         199  192883      H. Mkhitaryan     micki_taryan   29
# 200         200  192638      Marcos Alonso   marcosalonso28   27
# 201         201  192593         D. Suba_i_  danijel.subasic   33
# 202         202  190547            K. Glik      kamilglik25   30
# 203         203  189712       K. Strootman   kevinstrootman   28
#
#                                               Photo  Nationality  \
# 0    https://cdn.sofifa.org/players/4/19/158023.png    Argentina
# ...

# %%
soccer_transformed = soccer_df[['ID','Name', 'Instagram ID', 'Age', 'Nationality', 'Club',
                                 'Value', 'Wage', 'Overall']].copy()
soccer_transformed.head()
# Out:
#        ID               Name     Instagram ID  Age Nationality  \
# 0  158023           L. Messi         leomessi   31   Argentina
# 1   20801  Cristiano Ronaldo        cristiano   33    Portugal
# 2  190871          Neymar Jr         neymarjr   26      Brazil
# 3  193080             De Gea  d_degeaofficial   27       Spain
# 4  192985       K. De Bruyne    kevindebruyne   27     Belgium
#
#                   Club    Value   Wage  Overall
# 0         FC Barcelona  €110.5M  €565K       94
# 1             Juventus     €77M  €405K       94
# 2  Paris Saint-Germain  €118.5M  €290K       92
# 3    Manchester United     €72M  €260K       91
# 4      Manchester City    €102M  €355K       91

# %%
top_200 = soccer_transformed.head(206)
top_200
# Out:
#          ID               Name     Instagram ID  Age  Nationality  \
# 0    158023           L. Messi         leomessi   31    Argentina
# 1     20801  Cristiano Ronaldo        cristiano   33     Portugal
# 2    190871          Neymar Jr         neymarjr   26       Brazil
# 3    193080             De Gea  d_degeaofficial   27        Spain
# 4    192985       K. De Bruyne    kevindebruyne   27      Belgium
# ..      ...                ...              ...  ...          ...
# 201  192593         D. Suba_i_  danijel.subasic   33      Croatia
# 202  190547            K. Glik      kamilglik25   30       Poland
# 203  189712       K. Strootman   kevinstrootman   28  Netherlands
# 204  189068            B. Dost              NaN   29  Netherlands
# 205  188152              Oscar    oscar_emboaba   26       Brazil
#
#                        Club    Value   Wage  Overall
# 0              FC Barcelona  €110.5M  €565K       94
# 1                  Juventus     €77M  €405K       94
# ...

# %%
top_200.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 9 columns):
# ID              206 non-null int64
# Name            206 non-null object
# Instagram ID    200 non-null object
# Age             206 non-null int64
# Nationality     206 non-null object
# Club            206 non-null object
# Value           206 non-null object
# Wage            206 non-null object
# Overall         206 non-null int64
# dtypes: int64(3), object(6)
# memory usage: 14.6+ KB

# %%
top_200.isna().sum()
# Out:
# ID              0
# Name            0
# Instagram ID    6
# Age             0
# Nationality     0
# Club            0
# Value           0
# Wage            0
# Overall         0
# dtype: int64

# %%
top_200.dropna(axis=0, how='any', inplace=True)
# Out:
# C:\Users\Yusuf Senturk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
top_200.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 205
# Data columns (total 9 columns):
# ID              200 non-null int64
# Name            200 non-null object
# Instagram ID    200 non-null object
# Age             200 non-null int64
# Nationality     200 non-null object
# Club            200 non-null object
# Value           200 non-null object
# Wage            200 non-null object
# Overall         200 non-null int64
# dtypes: int64(3), object(6)
# memory usage: 15.6+ KB

# %%
top_200
# Out:
#          ID               Name     Instagram ID  Age  Nationality  \
# 0    158023           L. Messi         leomessi   31    Argentina
# 1     20801  Cristiano Ronaldo        cristiano   33     Portugal
# 2    190871          Neymar Jr         neymarjr   26       Brazil
# 3    193080             De Gea  d_degeaofficial   27        Spain
# 4    192985       K. De Bruyne    kevindebruyne   27      Belgium
# ..      ...                ...              ...  ...          ...
# 200  192638      Marcos Alonso   marcosalonso28   27        Spain
# 201  192593         D. Suba_i_  danijel.subasic   33      Croatia
# 202  190547            K. Glik      kamilglik25   30       Poland
# 203  189712       K. Strootman   kevinstrootman   28  Netherlands
# 205  188152              Oscar    oscar_emboaba   26       Brazil
#
#                        Club    Value   Wage  Overall
# 0              FC Barcelona  €110.5M  €565K       94
# 1                  Juventus     €77M  €405K       94
# ...

# %%
instagram_df = pd.read_csv("instagram.csv")

# %%
instagram_df
# Out:
#                        Club               Name     Instagram ID  No_followers  \
# 0              FC Barcelona           L. Messi         leomessi   149815811.0
# 1                  Juventus  Cristiano Ronaldo        cristiano   216921320.0
# 2       Paris Saint-Germain          Neymar Jr         neymarjr   138676674.0
# 3         Manchester United             De Gea  d_degeaofficial    10993679.0
# 4           Manchester City       K. De Bruyne    kevindebruyne    10920443.0
# ..                      ...                ...              ...           ...
# 195                 Chelsea      Marcos Alonso   marcosalonso28     1517600.0
# 196               AS Monaco         D. Suba_i_  danijel.subasic      441037.0
# 197               AS Monaco            K. Glik      kamilglik25      357727.0
# 198  Olympique de Marseille       K. Strootman   kevinstrootman      616558.0
# 199        Shanghai SIPG FC              Oscar    oscar_emboaba     5307225.0
#
#      No_following
# ...

# %%
instagram_transformed = instagram_df[['Name', 'Instagram ID', 'No_followers', 'No_following']].copy()
instagram_transformed
# Out:
#                   Name     Instagram ID  No_followers  No_following
# 0             L. Messi         leomessi   149815811.0         229.0
# 1    Cristiano Ronaldo        cristiano   216921320.0         447.0
# 2            Neymar Jr         neymarjr   138676674.0        1236.0
# 3               De Gea  d_degeaofficial    10993679.0         140.0
# 4         K. De Bruyne    kevindebruyne    10920443.0         331.0
# ..                 ...              ...           ...           ...
# 195      Marcos Alonso   marcosalonso28     1517600.0         354.0
# 196         D. Suba_i_  danijel.subasic      441037.0         355.0
# 197            K. Glik      kamilglik25      357727.0         553.0
# 198       K. Strootman   kevinstrootman      616558.0         195.0
# 199              Oscar    oscar_emboaba     5307225.0         351.0
#
# [200 rows x 4 columns]

# %%
merge = pd.merge(top_200, instagram_transformed)
merge
# Out:
#          ID               Name     Instagram ID  Age  Nationality  \
# 0    158023           L. Messi         leomessi   31    Argentina
# 1     20801  Cristiano Ronaldo        cristiano   33     Portugal
# 2    190871          Neymar Jr         neymarjr   26       Brazil
# 3    193080             De Gea  d_degeaofficial   27        Spain
# 4    192985       K. De Bruyne    kevindebruyne   27      Belgium
# ..      ...                ...              ...  ...          ...
# 195  192638      Marcos Alonso   marcosalonso28   27        Spain
# 196  192593         D. Suba_i_  danijel.subasic   33      Croatia
# 197  190547            K. Glik      kamilglik25   30       Poland
# 198  189712       K. Strootman   kevinstrootman   28  Netherlands
# 199  188152              Oscar    oscar_emboaba   26       Brazil
#
#                        Club    Value   Wage  Overall  No_followers  \
# 0              FC Barcelona  €110.5M  €565K       94   149815811.0
# ...

# %%
merge = merge[['ID','Name','Instagram ID', 'No_followers', 'No_following',
              'Age', 'Nationality', 'Club', 'Value', 'Wage', 'Overall']]

# %%
merge
# Out:
#          ID               Name     Instagram ID  No_followers  No_following  \
# 0    158023           L. Messi         leomessi   149815811.0         229.0
# 1     20801  Cristiano Ronaldo        cristiano   216921320.0         447.0
# 2    190871          Neymar Jr         neymarjr   138676674.0        1236.0
# 3    193080             De Gea  d_degeaofficial    10993679.0         140.0
# 4    192985       K. De Bruyne    kevindebruyne    10920443.0         331.0
# ..      ...                ...              ...           ...           ...
# 195  192638      Marcos Alonso   marcosalonso28     1517600.0         354.0
# 196  192593         D. Suba_i_  danijel.subasic      441037.0         355.0
# 197  190547            K. Glik      kamilglik25      357727.0         553.0
# 198  189712       K. Strootman   kevinstrootman      616558.0         195.0
# 199  188152              Oscar    oscar_emboaba     5307225.0         351.0
#
# ...

# %%
clubs = pd.read_csv("clubs_ranking.csv")
clubs
# Out:
#      rank  prev_rank                name                    league   off  \
# 0       1          1     Manchester City   Barclays Premier League  3.16
# 1       2          2       Bayern Munich         German Bundesliga  3.50
# 2       3          3           Liverpool   Barclays Premier League  2.87
# 3       4          4           Barcelona  Spanish Primera Division  2.90
# 4       5          5         Real Madrid  Spanish Primera Division  2.67
# ..    ...        ...                 ...                       ...   ...
# 624   625        625  Bethlehem Steel FC      United Soccer League  0.36
# 625   626        626        Macclesfield        English League Two  0.20
# 626   627        627    Cambridge United        English League Two  0.20
# 627   628        628           Stevenage        English League Two  0.20
# 628   629        629           Morecambe        English League Two  0.20
#
#       def    spi
# 0    0.21  94.80
# 1    0.38  94.44
# 2    0.31  91.91
# 3    0.43  90.33
# ...

# %%
clubs.head(10)
# Out:
#    rank  prev_rank                 name                    league   off   def  \
# 0     1          1      Manchester City   Barclays Premier League  3.16  0.21
# 1     2          2        Bayern Munich         German Bundesliga  3.50  0.38
# 2     3          3            Liverpool   Barclays Premier League  2.87  0.31
# 3     4          4            Barcelona  Spanish Primera Division  2.90  0.43
# 4     5          5          Real Madrid  Spanish Primera Division  2.67  0.37
# 5     6          6  Paris Saint-Germain            French Ligue 1  3.19  0.65
# 6     7          7             Juventus             Italy Serie A  2.44  0.54
# 7     8          8    Manchester United   Barclays Premier League  2.38  0.40
# 8     9          9              Chelsea   Barclays Premier League  2.44  0.47
# 9    10         10    Borussia Dortmund         German Bundesliga  2.58  0.56
#
#      spi
# 0  94.80
# 1  94.44
# 2  91.91
# 3  90.33
# 4  89.49
# 5  89.15
# 6  84.28
# 7  86.23
# 8  85.54
# ...

# %%
array = ['Manchester City', 'FC Bayern München', 'Liverpool', 'FC Barcelona', 'Real Madrid', 'Paris Saint-Germain',
        'Juventus', 'Manchester United', 'Chelsea', 'Borussia Dortmund']
top_10_clubs = merge.loc[(merge['Club'].isin(array))]
top_10_clubs
# Out:
#          ID               Name        Instagram ID  No_followers  \
# 0    158023           L. Messi            leomessi   149815811.0
# 1     20801  Cristiano Ronaldo           cristiano   216921320.0
# 2    190871          Neymar Jr            neymarjr   138676674.0
# 3    193080             De Gea     d_degeaofficial    10993679.0
# 4    192985       K. De Bruyne       kevindebruyne    10920443.0
# ..      ...                ...                 ...           ...
# 177  203574          J. Stones  johnstonesofficial      765808.0
# 179  202166         J. Draxler     draxlerofficial     4086987.0
# 183  200724    Nacho Fernandez         nachofdez90     6090350.0
# 187  199564      Sergi Roberto        sergiroberto     7398017.0
# 195  192638      Marcos Alonso      marcosalonso28     1517600.0
#
#      No_following  Age Nationality                 Club    Value   Wage  \
# 0           229.0   31   Argentina         FC Barcelona  €110.5M  €565K
# ...

# %%
country = pd.read_csv("country_ranking.csv")
country
# Out:
#      rank         name    confed   off   def    spi
# 0       1        Spain      UEFA  3.52  0.56  91.92
# 1       2       Brazil  CONMEBOL  2.88  0.37  90.29
# 2       3      Germany      UEFA  3.24  0.61  89.43
# 3       4      Belgium      UEFA  3.05  0.59  88.29
# 4       5    Argentina  CONMEBOL  2.67  0.41  88.04
# ..    ...          ...       ...   ...   ...    ...
# 212   213       Tuvalu       OFC  0.38  5.62   0.70
# 213   214  Timor-Leste       AFC  0.33  5.56   0.64
# 214   215        Macau       AFC  0.20  5.11   0.60
# 215   216        Samoa       OFC  0.20  5.78   0.34
# 216   217        Tonga       OFC  0.20  6.08   0.26
#
# [217 rows x 6 columns]

# %%
country.head(10)
# Out:
#    rank         name    confed   off   def    spi
# 0     1        Spain      UEFA  3.52  0.56  91.92
# 1     2       Brazil  CONMEBOL  2.88  0.37  90.29
# 2     3      Germany      UEFA  3.24  0.61  89.43
# 3     4      Belgium      UEFA  3.05  0.59  88.29
# 4     5    Argentina  CONMEBOL  2.67  0.41  88.04
# 5     6      England      UEFA  2.81  0.53  87.20
# 6     7  Netherlands      UEFA  2.76  0.56  86.24
# 7     8       France      UEFA  2.65  0.56  85.13
# 8     9     Colombia  CONMEBOL  2.21  0.40  83.26
# 9    10        Italy      UEFA  2.40  0.51  83.26

# %%
array_country = ['Spain', 'Brazil', 'Germany', 'Belgium', 'Argentina', 'England',
        'Netherlands', 'France', 'Colombia', 'Italy']
top_10_countries = merge.loc[(merge['Nationality'].isin(array_country))]
top_10_countries
# Out:
#          ID           Name     Instagram ID  No_followers  No_following  Age  \
# 0    158023       L. Messi         leomessi   149815811.0         229.0   31
# 2    190871      Neymar Jr         neymarjr   138676674.0        1236.0   26
# 3    193080         De Gea  d_degeaofficial    10993679.0         140.0   27
# 4    192985   K. De Bruyne    kevindebruyne    10920443.0         331.0   27
# 5    183277      E. Hazard    hazardeden_10    26740811.0         145.0   27
# ..      ...            ...              ...           ...           ...  ...
# 191  194404           Neto      netoomurara     1064043.0         307.0   28
# 192  193698     O. Baumann     olibaumann90       30549.0        1208.0   28
# 195  192638  Marcos Alonso   marcosalonso28     1517600.0         354.0   27
# 198  189712   K. Strootman   kevinstrootman      616558.0         195.0   28
# 199  188152          Oscar    oscar_emboaba     5307225.0         351.0   26
#
# ...

# %%
top_10_clubs_and_countries = merge.loc[(merge['Club'].isin(array)) & (merge['Nationality'].isin(array_country))]
top_10_clubs_and_countries
# Out:
#          ID             Name        Instagram ID  No_followers  No_following  \
# 0    158023         L. Messi            leomessi   149815811.0         229.0
# 2    190871        Neymar Jr            neymarjr   138676674.0        1236.0
# 3    193080           De Gea     d_degeaofficial    10993679.0         140.0
# 4    192985     K. De Bruyne       kevindebruyne    10920443.0         331.0
# 5    183277        E. Hazard       hazardeden_10    26740811.0         145.0
# ..      ...              ...                 ...           ...           ...
# 177  203574        J. Stones  johnstonesofficial      765808.0         155.0
# 179  202166       J. Draxler     draxlerofficial     4086987.0         156.0
# 183  200724  Nacho Fernandez         nachofdez90     6090350.0         529.0
# 187  199564    Sergi Roberto        sergiroberto     7398017.0         576.0
# 195  192638    Marcos Alonso      marcosalonso28     1517600.0         354.0
#
# ...
